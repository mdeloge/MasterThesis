# %%
import urllib2
import csv
import pandas as pd

# %%
response = urllib2.urlopen('https://energyiddev.blob.core.windows.net/jouleboulevard2/Jouleboulevard_metadata.csv')
csv_file = csv.reader(response)

# %%
df = pd.read_csv('https://energyiddev.blob.core.windows.net/jouleboulevard2/Jouleboulevard_metadata.csv', delimiter=';')

# %%
df.head()
# Out:
#                                ﻿MeterId              MeterName         Type  \
# 0  404AEB88-F5F8-436E-94F7-223EE87D8BB7  Elektriciteit (nacht)  electricity
# 1  5553EC7E-D2F7-4CF0-BD2A-27CA3B95FA00         Aardgas Flukso  natural gas
# 2  47DB61A1-050F-4900-A7AE-AECF2E7AF5D8                Aardgas  natural gas
# 3  5CEC0721-2858-4BA4-B705-E53C540E1016   Elektriciteit Flukso  electricity
# 4  EE47B462-9C04-4E7E-912D-EB6F9D8E84BF    Elektriciteit (dag)  electricity
#
#   Unit RecordNumber  RecordName   DwellingType ConstructionYear  \
# 0  kwh  EA-14106111  G07 Mykene  AttachedHouse              NaN
# 1    l  EA-14106111  G07 Mykene  AttachedHouse              NaN
# 2  cbm  EA-14106111  G07 Mykene  AttachedHouse              NaN
# 3   wh  EA-14106111  G07 Mykene  AttachedHouse              NaN
# 4  kwh  EA-14106111  G07 Mykene  AttachedHouse              NaN
#
#   RenovationYear Country     ...      Category  EnergyEfficiency  \
# ...

# %%
df.to_csv("Jouleboulevard_metadata.csv", sep=';')
